# %% [markdown]
# # **2. ANÁLISIS DESCRIPTIVO**

# %%
import pandas as pd
data = 'C:\\Users\\Fukushima\\Documents\\GitHub\\ProyectoFinalVV\\src\\books.csv'
df = pd.read_csv(data, on_bad_lines='skip')
df.head(10)
# Out:
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_5148\81729858.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data, on_bad_lines='skip')
#    Id                                               Name RatingDist1  \
# 0   1  Harry Potter and the Half-Blood Prince (Harry ...      1:9896
# 1   2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 2   3  Harry Potter and the Sorcerer's Stone (Harry P...    1:108202
# 3   4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4   5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
# 5   6  Harry Potter and the Goblet of Fire (Harry Pot...      1:9419
# 6   8  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       1:402
# 7   9  Unauthorized Harry Potter Book Seven News: "Ha...         1:0
# 8  10       Harry Potter Collection (Harry Potter, #1-6)       1:257
# 9  12  The Ultimate Hitchhiker's Guide: Five Complete...      1:3443
#
#    pagesNumber RatingDist4 RatingDistTotal  PublishMonth  PublishDay  \
# 0        652.0    4:556485   total:2298124            16           9
# 1        870.0    4:604283   total:2358637             1           9
# 2        309.0   4:1513191   total:6587388             1          11
# 3        352.0    4:706082   total:2560657             1          11
# 4        435.0    4:630534   total:2610317             1           5
# 5        734.0    4:606800   total:2431085            28           9
# 6       2690.0      4:4650     total:43968            13           9
# 7        152.0         4:7        total:28            26           4
# 8       3342.0      4:4358     total:30313            12           9
# 9        815.0     4:75683    total:274268             1          11
#
#          Publisher  CountsOfReview  ...  Language                 Authors  \
# 0  Scholastic Inc.           28062  ...       eng            J.K. Rowling
# 1  Scholastic Inc.           29770  ...       eng            J.K. Rowling
# 2   Scholastic Inc           75911  ...       eng            J.K. Rowling
# 3       Scholastic             244  ...       eng            J.K. Rowling
# 4  Scholastic Inc.           37093  ...       eng            J.K. Rowling
# 5       Scholastic           31978  ...       eng            J.K. Rowling
# 6       Scholastic             166  ...       eng            J.K. Rowling
# 7     Nimble Books               1  ...     en-US  W. Frederick Zimmerman
# 8       Scholastic             809  ...       eng            J.K. Rowling
# 9   Gramercy Books             255  ...       eng           Douglas Adams
#
#   Rating  RatingDist2 RatingDist5        ISBN RatingDist3 Description  \
# 0   4.57      2:25317   5:1546466         NaN    3:159960         NaN
# 1   4.50      2:37005   5:1493113  0439358078    3:211781         NaN
# 2   4.47     2:130310   5:4268227         NaN    3:567458         NaN
# 3   4.42      2:49353   5:1504505  0439554896    3:288821         NaN
# 4   4.57      2:24849   5:1749958  043965548X    3:194848         NaN
# 5   4.56      2:24282   5:1612165         NaN    3:178419         NaN
# 6   4.78        2:283     5:37432  0439682584      3:1201         NaN
# 7   3.79          2:5        5:10  0976540606         3:6         NaN
# 8   4.73        2:218     5:24406  0439827604      3:1074         NaN
# 9   4.37       2:7613    5:157499  0517226952     3:30030         NaN
#
#   Count of text reviews  PagesNumber
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
# 5                   NaN          NaN
# 6                   NaN          NaN
# 7                   NaN          NaN
# 8                   NaN          NaN
# 9                   NaN          NaN
#
# [10 rows x 21 columns]

# %% [markdown]
# # Variables númericas

# %%
import matplotlib.pyplot as plt
import seaborn as sns


sns.set_palette("husl", df.shape[1])

df.hist(bins=50, figsize=(20, 15))
plt.show()

# %% [markdown]
# # Valores Categóricas

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una paleta personalizada en la gama de rosa y morado
paleta_rosa_morado = sns.color_palette(["#FF69B4", "#DB7093", "#C71585", "#800080", "#DA70D6", "#BA55D3", "#EE82EE"])

# Gráfico de conteo para autores
plt.figure(figsize=(10, 6))
sns.countplot(y=df['Authors'], order=df['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
plt.title('Top 10 autores Más Frecuentes')
plt.xlabel('Frecuencia')
plt.ylabel('Libros')
plt.show()

# Gráfico de conteo para publicistas
plt.figure(figsize=(10, 6))
sns.countplot(y=df['Publisher'], order=df['Publisher'].value_counts().index[:10], palette=paleta_rosa_morado)
plt.title('Top 10 editoriales Más Frecuentes')
plt.xlabel('Frecuencia')
plt.ylabel('editoriales')
plt.show()
# Out:
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_5148\691497574.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Authors'], order=df['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_5148\691497574.py:9: UserWarning:
# The palette list has fewer values (7) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(y=df['Authors'], order=df['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_5148\691497574.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Publisher'], order=df['Publisher'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_5148\691497574.py:17: UserWarning:
# The palette list has fewer values (7) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(y=df['Publisher'], order=df['Publisher'].value_counts().index[:10], palette=paleta_rosa_morado)

# %% [markdown]
# # Valores nulos

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1810605 entries, 0 to 1810604
# Data columns (total 21 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   Id                     int64
#  1   Name                   object
#  2   RatingDist1            object
#  3   pagesNumber            float64
#  4   RatingDist4            object
#  5   RatingDistTotal        object
#  6   PublishMonth           int64
#  7   PublishDay             int64
#  8   Publisher              object
#  9   CountsOfReview         int64
#  10  PublishYear            int64
#  11  Language               object
#  12  Authors                object
#  13  Rating                 float64
#  14  RatingDist2            object
#  15  RatingDist5            object
#  16  ISBN                   object
#  17  RatingDist3            object
#  18  Description            object
#  19  Count of text reviews  float64
#  20  PagesNumber            float64
# dtypes: float64(4), int64(5), object(12)
# memory usage: 290.1+ MB

# %% [markdown]
# # Descripción

# %%
df.describe()
# Out:
#                  Id   pagesNumber  PublishMonth    PublishDay  CountsOfReview  \
# count  1.810605e+06  7.953730e+05  1.810605e+06  1.810605e+06    1.810605e+06
# mean   2.134879e+06  2.806851e+02  7.653788e+00  8.022824e+00    1.168828e+01
# std    1.414629e+06  5.674289e+03  7.684581e+00  8.503850e+00    2.983463e+02
# min    1.000000e+00  0.000000e+00  1.000000e+00  1.000000e+00    0.000000e+00
# 25%    8.094600e+05  1.500000e+02  1.000000e+00  1.000000e+00    0.000000e+00
# 50%    2.061550e+06  2.400000e+02  6.000000e+00  5.000000e+00    0.000000e+00
# 75%    3.229534e+06  3.400000e+02  1.100000e+01  1.100000e+01    2.000000e+00
# max    4.846451e+06  4.517845e+06  3.100000e+01  3.100000e+01    1.544470e+05
#
#         PublishYear        Rating  Count of text reviews   PagesNumber
# count  1.810605e+06  1.810605e+06          369992.000000  1.015232e+06
# mean   1.997817e+03  2.882877e+00               7.228535  2.735816e+02
# std    8.884426e+01  1.731395e+00             129.799158  4.521817e+03
# min    1.000000e+00  0.000000e+00               0.000000  0.000000e+00
# 25%    1.993000e+03  1.000000e+00               0.000000  1.410000e+02
# 50%    2.000000e+03  3.670000e+00               1.000000  2.320000e+02
# 75%    2.005000e+03  4.000000e+00               3.000000  3.360000e+02
# max    6.553500e+04  5.000000e+00           43652.000000  4.517845e+06

# %% [markdown]
# # Tamaño de muestra

# %%
print(f'Filas:{df.shape[0]}')
print(f'Columnas:{df.shape[1]}')
# Out:
# Filas:1810605
# Columnas:21

# %% [markdown]
# # Nombres de las columnas

# %%
df.columns
# Out:
# Index(['Id', 'Name', 'RatingDist1', 'pagesNumber', 'RatingDist4',
#        'RatingDistTotal', 'PublishMonth', 'PublishDay', 'Publisher',
#        'CountsOfReview', 'PublishYear', 'Language', 'Authors', 'Rating',
#        'RatingDist2', 'RatingDist5', 'ISBN', 'RatingDist3', 'Description',
#        'Count of text reviews', 'PagesNumber'],
#       dtype='object')

# %% [markdown]
# # Valores Únicos

# %%
df.nunique()
# Out:
# Id                       1810410
# Name                     1606554
# RatingDist1                 8550
# pagesNumber                 2401
# RatingDist4                28532
# RatingDistTotal            43012
# PublishMonth                  31
# PublishDay                    31
# Publisher                  78665
# CountsOfReview              2828
# PublishYear                  199
# Language                     124
# Authors                   668506
# Rating                       337
# RatingDist2                12860
# RatingDist5                29009
# ISBN                     1804615
# RatingDist3                23253
# Description              1052954
# Count of text reviews        843
# PagesNumber                 2741
# dtype: int64
