# %% [markdown]
# # **3. EDA**

# %%
import pandas as pd
data = 'C:\\Users\\Fukushima\\Documents\\GitHub\\ProyectoFinalVV\\src\\books.csv'
df = pd.read_csv(data)
print(df.head())
# Out:
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_12972\2816091405.py:3: DtypeWarning: Columns (18) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(data)
#    Id                                               Name RatingDist1  \
# 0   1  Harry Potter and the Half-Blood Prince (Harry ...      1:9896
# 1   2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 2   3  Harry Potter and the Sorcerer's Stone (Harry P...    1:108202
# 3   4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4   5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
#
#    pagesNumber RatingDist4 RatingDistTotal  PublishMonth  PublishDay  \
# 0        652.0    4:556485   total:2298124            16           9
# 1        870.0    4:604283   total:2358637             1           9
# 2        309.0   4:1513191   total:6587388             1          11
# 3        352.0    4:706082   total:2560657             1          11
# 4        435.0    4:630534   total:2610317             1           5
#
#          Publisher  CountsOfReview  ...  Language       Authors Rating  \
# 0  Scholastic Inc.           28062  ...       eng  J.K. Rowling   4.57
# 1  Scholastic Inc.           29770  ...       eng  J.K. Rowling   4.50
# 2   Scholastic Inc           75911  ...       eng  J.K. Rowling   4.47
# 3       Scholastic             244  ...       eng  J.K. Rowling   4.42
# 4  Scholastic Inc.           37093  ...       eng  J.K. Rowling   4.57
#
#    RatingDist2 RatingDist5        ISBN RatingDist3 Description  \
# 0      2:25317   5:1546466         NaN    3:159960         NaN
# 1      2:37005   5:1493113  0439358078    3:211781         NaN
# 2     2:130310   5:4268227         NaN    3:567458         NaN
# 3      2:49353   5:1504505  0439554896    3:288821         NaN
# 4      2:24849   5:1749958  043965548X    3:194848         NaN
#
#   Count of text reviews  PagesNumber
# 0                   NaN          NaN
# 1                   NaN          NaN
# 2                   NaN          NaN
# 3                   NaN          NaN
# 4                   NaN          NaN
#
# [5 rows x 21 columns]

# %%
df.shape
# Out:
# (1810605, 21)

# %% [markdown]
# # DESCRIPCIÓN DE LAS VARIABLES

# %% [markdown]
# Como estos datos son obtenidos de GoodReads, explicaré que es cada variable:
# - Id: código de identificación de cada libro creado por Goodreads.
# - Name: Nombre del libro.
# - RatingDist1: cantidad de veces que le han dado 1 estrella.
# - pagesNumber: Número de páginas de un libro.
# - RatingDist4: cantidad de veces que le han dado 4 estrellas.
# - RatingDistTotal: Número de valoraciones totales.
# - PublishMonth: Mes de publicación.
# - PublishDay: Día de publicación.
# - Publisher: editorial.
# - CountsOfReview: Número de veces que han escrito una reseña.
# - PublishYear: año de publicación.
# - Language: idioma.
# - Authors: autores.
# - Rating: puntuación.
# - RatingDist2: Número de veces valorado con 2 estrellas.
# - RatingDist5: Número de veces valorado con 5 estrellas.
# - ISBN: código del libro, diferente al ID, el ISBN un identificador internacional único para cada libro.
# - RatingDist3: Número de veces valorado con 3 estrellas.
# - Description: La descripción de cada libro.
# - Count of text reviews: Cantidade de reseñas escritas.
# - PagesNumber: número de páginas.

# %%
df.describe(include='all')
# Out:
#                   Id       Name RatingDist1   pagesNumber RatingDist4  \
# count   1.810605e+06    1810605     1810605  7.953730e+05     1810605
# unique           NaN    1606554        8550           NaN       28532
# top              NaN  Jane Eyre         1:0           NaN         4:0
# freq             NaN         23     1257609           NaN      691807
# mean    2.134879e+06        NaN         NaN  2.806851e+02         NaN
# std     1.414629e+06        NaN         NaN  5.674289e+03         NaN
# min     1.000000e+00        NaN         NaN  0.000000e+00         NaN
# 25%     8.094600e+05        NaN         NaN  1.500000e+02         NaN
# 50%     2.061550e+06        NaN         NaN  2.400000e+02         NaN
# 75%     3.229534e+06        NaN         NaN  3.400000e+02         NaN
# max     4.846451e+06        NaN         NaN  4.517845e+06         NaN
#
#        RatingDistTotal  PublishMonth    PublishDay  Publisher  CountsOfReview  \
# count          1810605  1.810605e+06  1.810605e+06    1793139    1.810605e+06
# unique           43012           NaN           NaN      78665             NaN
# top            total:0           NaN           NaN  Routledge             NaN
# freq            447379           NaN           NaN      37027             NaN
# mean               NaN  7.653788e+00  8.022824e+00        NaN    1.168828e+01
# std                NaN  7.684581e+00  8.503850e+00        NaN    2.983463e+02
# min                NaN  1.000000e+00  1.000000e+00        NaN    0.000000e+00
# 25%                NaN  1.000000e+00  1.000000e+00        NaN    0.000000e+00
# 50%                NaN  6.000000e+00  5.000000e+00        NaN    0.000000e+00
# 75%                NaN  1.100000e+01  1.100000e+01        NaN    2.000000e+00
# max                NaN  3.100000e+01  3.100000e+01        NaN    1.544470e+05
#
#         ...  Language    Authors        Rating  RatingDist2 RatingDist5  \
# count   ...    244809    1810605  1.810605e+06      1810605     1810605
# unique  ...       124     668506           NaN        12860       29009
# top     ...       eng  Anonymous           NaN          2:0         5:0
# freq    ...    175100       2817           NaN      1028033      712450
# mean    ...       NaN        NaN  2.882877e+00          NaN         NaN
# std     ...       NaN        NaN  1.731395e+00          NaN         NaN
# min     ...       NaN        NaN  0.000000e+00          NaN         NaN
# 25%     ...       NaN        NaN  1.000000e+00          NaN         NaN
# 50%     ...       NaN        NaN  3.670000e+00          NaN         NaN
# 75%     ...       NaN        NaN  4.000000e+00          NaN         NaN
# max     ...       NaN        NaN  5.000000e+00          NaN         NaN
#
#               ISBN RatingDist3  \
# count      1804810     1810605
# unique     1804615       23253
# top     0671578294         3:0
# freq             2      738343
# mean           NaN         NaN
# std            NaN         NaN
# min            NaN         NaN
# 25%            NaN         NaN
# 50%            NaN         NaN
# 75%            NaN         NaN
# max            NaN         NaN
#
#                                               Description  \
# count                                             1136629
# unique                                            1052954
# top     This scarce antiquarian book is a facsimile re...
# freq                                                 4901
# mean                                                  NaN
# std                                                   NaN
# min                                                   NaN
# 25%                                                   NaN
# 50%                                                   NaN
# 75%                                                   NaN
# max                                                   NaN
#
#        Count of text reviews   PagesNumber
# count          369992.000000  1.015232e+06
# unique                   NaN           NaN
# top                      NaN           NaN
# freq                     NaN           NaN
# mean                7.228535  2.735816e+02
# std               129.799158  4.521817e+03
# min                 0.000000  0.000000e+00
# 25%                 0.000000  1.410000e+02
# 50%                 1.000000  2.320000e+02
# 75%                 3.000000  3.360000e+02
# max             43652.000000  4.517845e+06
#
# [11 rows x 21 columns]

# %% [markdown]
# En base a esta información podré determinar que columna necesito y cual no.
# - Id: Este código no lo necesito ya que es algo de la página, **no representa información útil.**
# - Name: Esta columna si es importante, porque es de donde sacaremos los nombres para hacer la busqueda. **Información importante**
# - RatingDist1: Esta columna no la considero importante, porque no me enfocaré en libros con menos de 3 estrellas. **no representa información útil.**
# - pagesNumber: Este si porque quiero filtrar por número de páginas. **Información importante**
# - RatingDist4: Esta columna la considero importante, porque me enfocaré en libros con más de 3 estrellas. **Información importante**
# - RatingDistTotal: Esta columna  si la considero importante ya que en base al rate serán las recomendaciones **Información importante**
# - PublishMonth: No me genera utilidad saber el mes de publicación. **no representa información útil.**
# - PublishDay: No me genera utilidad saber el día de publicación.**no representa información útil.**
# - Publisher: No es importante la editorial, porque esto también puede variar.**no representa información útil.** .
# - CountsOfReview: La mantendré pero no la considero muy importante
# - PublishYear: No me genera utilidad saber el año de publicación. **no representa información útil.**
# - Language: El idioma de un libro de hoy en día no es importante, porque los lubros pueden ser traducidos en muchos idiomas. **no representa información útil.** .
# - Authors: Representa información útil para poder filtrar las recomendaciones **Información importante**
# - Rating: este si lo considero importante ya que es la base de las recomendaciones **Información importante**
# - RatingDist2: Esta columna no la considero importante, porque no me enfocaré en libros con menos de 3 estrellas. **no representa información útil.**
# - RatingDist5: Número de veces valorado con 5 estrellas.**Información importante**
# - ISBN: **no representa información útil.**
# - Description: Esta columna está vacía en casi la mayor parte de los datos por tanto no la utilizaré.**no representa información útil.** .
# - Count of text reviews: **no representa información útil.** .
# - PagesNumber: Considero que se puede hacer las recomendaciones a base al número de páginas también. **Información importante**

# %% [markdown]
# Mi objetivo de estudio ha sido buscar unas recomendaciones más "perfectas" utilizando la base de datos de Goodreads ya que es la página más completa de datos, en donde los lectores pueden puntuar y a su vez escribir reseñas de los libros leídos. Con la finalidad de crear un modelo de machine que pueda recomendar con mayor acierto un libro.
#
# Trabajaré con un dataframe de de 22 columnas y 1810605 de filas, mi target para las recomendaciones serían las columnas de rate, autor y número de páginas, considero utilizar las ratingDist3,4 y 5 ya que estas muestran la cantidad de veces que han sido puntuadas con una puntuación superior a 3, podría utilizarlo para el filtrado.
#
# Acontinuación eliminaré las columnas con informacion irrelavante ya que existen columnas y datos que no me aportan información relevante.

# %% [markdown]
# *Tengo dos columnas que contienen la misma información y me servirían más en una sola columna, uniré pagesNumber y PagesNumber en una sola columna para tener todo mejor organizado.*

# %%
import pandas as pd

# Combinar las dos columnas en una sola
# Si alguna de las dos columnas tiene valores nulos, se llenará con el valor de la otra columna
df['pagesNumber'] = df['pagesNumber'].combine_first(df['PagesNumber'])

# Eliminar la columna duplicada
df = df.drop(columns=['PagesNumber'])

# Verificar el resultado
print(df.head())
# Out:
#    Id                                               Name RatingDist1  \
# 0   1  Harry Potter and the Half-Blood Prince (Harry ...      1:9896
# 1   2  Harry Potter and the Order of the Phoenix (Har...     1:12455
# 2   3  Harry Potter and the Sorcerer's Stone (Harry P...    1:108202
# 3   4  Harry Potter and the Chamber of Secrets (Harry...     1:11896
# 4   5  Harry Potter and the Prisoner of Azkaban (Harr...     1:10128
#
#    pagesNumber RatingDist4 RatingDistTotal  PublishMonth  PublishDay  \
# 0        652.0    4:556485   total:2298124            16           9
# 1        870.0    4:604283   total:2358637             1           9
# 2        309.0   4:1513191   total:6587388             1          11
# 3        352.0    4:706082   total:2560657             1          11
# 4        435.0    4:630534   total:2610317             1           5
#
#          Publisher  CountsOfReview  PublishYear Language       Authors  \
# 0  Scholastic Inc.           28062         2006      eng  J.K. Rowling
# 1  Scholastic Inc.           29770         2004      eng  J.K. Rowling
# 2   Scholastic Inc           75911         2003      eng  J.K. Rowling
# 3       Scholastic             244         2003      eng  J.K. Rowling
# 4  Scholastic Inc.           37093         2004      eng  J.K. Rowling
#
#    Rating RatingDist2 RatingDist5        ISBN RatingDist3 Description  \
# 0    4.57     2:25317   5:1546466         NaN    3:159960         NaN
# 1    4.50     2:37005   5:1493113  0439358078    3:211781         NaN
# 2    4.47    2:130310   5:4268227         NaN    3:567458         NaN
# 3    4.42     2:49353   5:1504505  0439554896    3:288821         NaN
# 4    4.57     2:24849   5:1749958  043965548X    3:194848         NaN
#
#    Count of text reviews
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN

# %%
print(f'Filas:{df.shape[0]}')
print(f'Columnas:{df.shape[1]}')
# Out:
# Filas:1810605
# Columnas:20

# %%
df.drop(["Id", "RatingDist1", "PublishMonth", "PublishDay", "Publisher", "PublishYear", "Language", "ISBN", "Description", "Count of text reviews", "RatingDist2"], axis=1, inplace=True)

print("Se han eliminado 11 columnas")
df.head(10)
# Out:
# Se han eliminado 11 columnas
#                                                 Name  pagesNumber RatingDist4  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...        652.0    4:556485
# 1  Harry Potter and the Order of the Phoenix (Har...        870.0    4:604283
# 2  Harry Potter and the Sorcerer's Stone (Harry P...        309.0   4:1513191
# 3  Harry Potter and the Chamber of Secrets (Harry...        352.0    4:706082
# 4  Harry Potter and the Prisoner of Azkaban (Harr...        435.0    4:630534
# 5  Harry Potter and the Goblet of Fire (Harry Pot...        734.0    4:606800
# 6  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       2690.0      4:4650
# 7  Unauthorized Harry Potter Book Seven News: "Ha...        152.0         4:7
# 8       Harry Potter Collection (Harry Potter, #1-6)       3342.0      4:4358
# 9  The Ultimate Hitchhiker's Guide: Five Complete...        815.0     4:75683
#
#   RatingDistTotal  CountsOfReview                 Authors  Rating RatingDist5  \
# 0   total:2298124           28062            J.K. Rowling    4.57   5:1546466
# 1   total:2358637           29770            J.K. Rowling    4.50   5:1493113
# 2   total:6587388           75911            J.K. Rowling    4.47   5:4268227
# 3   total:2560657             244            J.K. Rowling    4.42   5:1504505
# 4   total:2610317           37093            J.K. Rowling    4.57   5:1749958
# 5   total:2431085           31978            J.K. Rowling    4.56   5:1612165
# 6     total:43968             166            J.K. Rowling    4.78     5:37432
# 7        total:28               1  W. Frederick Zimmerman    3.79        5:10
# 8     total:30313             809            J.K. Rowling    4.73     5:24406
# 9    total:274268             255           Douglas Adams    4.37    5:157499
#
#   RatingDist3
# 0    3:159960
# 1    3:211781
# 2    3:567458
# 3    3:288821
# 4    3:194848
# 5    3:178419
# 6      3:1201
# 7         3:6
# 8      3:1074
# 9     3:30030

# %% [markdown]
# Ahora cuento con un total de 9 columnas; 2 columnas categóricas y 7 numéricas.

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                       Name  pagesNumber  \
# 0        Harry Potter and the Half-Blood Prince (Harry ...        652.0
# 1        Harry Potter and the Order of the Phoenix (Har...        870.0
# 2        Harry Potter and the Sorcerer's Stone (Harry P...        309.0
# 3        Harry Potter and the Chamber of Secrets (Harry...        352.0
# 4        Harry Potter and the Prisoner of Azkaban (Harr...        435.0
# ...                                                    ...          ...
# 1810600  Gendered Talk at Work: Constructing Gender Ide...        251.0
# 1810601  Good Will Toward Men: Women Talk Candidly abou...        231.0
# 1810602  Would You Rather . . . ?: The Outrageous Book ...        400.0
# 1810603  Addictions Treatment for Older Adults: Evaluat...        258.0
# 1810604                                     Within/Without         36.0
#
#         RatingDist4 RatingDistTotal  CountsOfReview            Authors  \
# 0          4:556485   total:2298124           28062       J.K. Rowling
# 1          4:604283   total:2358637           29770       J.K. Rowling
# 2         4:1513191   total:6587388           75911       J.K. Rowling
# 3          4:706082   total:2560657             244       J.K. Rowling
# 4          4:630534   total:2610317           37093       J.K. Rowling
# ...             ...             ...             ...                ...
# 1810600         4:3        total:25               0      Janet  Holmes
# 1810601         4:0         total:0               0        Jack Kammer
# 1810602        4:35       total:121              14         Randy Horn
# 1810603         4:0         total:0               0     Kathryn Graham
# 1810604         4:0         total:2               0  Kathryn T.S. Bass
#
#          Rating RatingDist5 RatingDist3
# 0          4.57   5:1546466    3:159960
# 1          4.50   5:1493113    3:211781
# 2          4.47   5:4268227    3:567458
# 3          4.42   5:1504505    3:288821
# 4          4.57   5:1749958    3:194848
# ...         ...         ...         ...
# 1810600    4.28        5:15         3:6
# 1810601    0.00         5:0         3:0
# 1810602    3.81        5:39        3:34
# 1810603    0.00         5:0         3:0
# 1810604    5.00         5:2         3:0
#
# [1810605 rows x 9 columns]>

# %% [markdown]
# Ahora filtraré y eliminaré los datos cuyo valor de rating es menor a 3.5

# %%
import pandas as pd

# Filtrar los libros que tienen un rating mayor o igual a 3.5
df = df[df['Rating'] >= 3.5]

# Verificar el resultado
print("Libros con rating mayor o igual a 3.5:")
print(df.head())
# Out:
# Libros con rating mayor o igual a 3.5:
#                                                 Name  pagesNumber RatingDist4  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...        652.0    4:556485
# 1  Harry Potter and the Order of the Phoenix (Har...        870.0    4:604283
# 2  Harry Potter and the Sorcerer's Stone (Harry P...        309.0   4:1513191
# 3  Harry Potter and the Chamber of Secrets (Harry...        352.0    4:706082
# 4  Harry Potter and the Prisoner of Azkaban (Harr...        435.0    4:630534
#
#   RatingDistTotal  CountsOfReview       Authors  Rating RatingDist5  \
# 0   total:2298124           28062  J.K. Rowling    4.57   5:1546466
# 1   total:2358637           29770  J.K. Rowling    4.50   5:1493113
# 2   total:6587388           75911  J.K. Rowling    4.47   5:4268227
# 3   total:2560657             244  J.K. Rowling    4.42   5:1504505
# 4   total:2610317           37093  J.K. Rowling    4.57   5:1749958
#
#   RatingDist3
# 0    3:159960
# 1    3:211781
# 2    3:567458
# 3    3:288821
# 4    3:194848

# %%
df.info
# Out:
# <bound method DataFrame.info of                                                       Name  pagesNumber  \
# 0        Harry Potter and the Half-Blood Prince (Harry ...        652.0
# 1        Harry Potter and the Order of the Phoenix (Har...        870.0
# 2        Harry Potter and the Sorcerer's Stone (Harry P...        309.0
# 3        Harry Potter and the Chamber of Secrets (Harry...        352.0
# 4        Harry Potter and the Prisoner of Azkaban (Harr...        435.0
# ...                                                    ...          ...
# 1810598  Gender Talk: The Struggle For Women's Equality...        336.0
# 1810599         School Talk: Gender and Adolescent Culture        209.0
# 1810600  Gendered Talk at Work: Constructing Gender Ide...        251.0
# 1810602  Would You Rather . . . ?: The Outrageous Book ...        400.0
# 1810604                                     Within/Without         36.0
#
#         RatingDist4 RatingDistTotal  CountsOfReview                Authors  \
# 0          4:556485   total:2298124           28062           J.K. Rowling
# 1          4:604283   total:2358637           29770           J.K. Rowling
# 2         4:1513191   total:6587388           75911           J.K. Rowling
# 3          4:706082   total:2560657             244           J.K. Rowling
# 4          4:630534   total:2610317           37093           J.K. Rowling
# ...             ...             ...             ...                    ...
# 1810598        4:11        total:59               2  Johnnetta Betsch Cole
# 1810599        4:10        total:23               3             Donna Eder
# 1810600         4:3        total:25               0          Janet  Holmes
# 1810602        4:35       total:121              14             Randy Horn
# 1810604         4:0         total:2               0      Kathryn T.S. Bass
#
#          Rating RatingDist5 RatingDist3
# 0          4.57   5:1546466    3:159960
# 1          4.50   5:1493113    3:211781
# 2          4.47   5:4268227    3:567458
# 3          4.42   5:1504505    3:288821
# 4          4.57   5:1749958    3:194848
# ...         ...         ...         ...
# 1810598    4.03        5:27        3:18
# 1810599    3.57         5:2        3:10
# 1810600    4.28        5:15         3:6
# 1810602    3.81        5:39        3:34
# 1810604    5.00         5:2         3:0
#
# [1073666 rows x 9 columns]>

# %% [markdown]
# Se han eliminado 736,939 datos al filtrar los libros con un rating menor a 3,5 estrellas

# %% [markdown]
# He observado que la columna Counts Of Reviews no me proporciona una información que necesito ya que esta columna cuenta las reviews escritas y este dato no lo estoy estudiando.

# %%
df.drop(['CountsOfReview'], axis=1, inplace=True)

print("Se ha eliminado 1 columna")
df.head(10)
# Out:
# Se ha eliminado 1 columna
#                                                 Name  pagesNumber RatingDist4  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...        652.0    4:556485
# 1  Harry Potter and the Order of the Phoenix (Har...        870.0    4:604283
# 2  Harry Potter and the Sorcerer's Stone (Harry P...        309.0   4:1513191
# 3  Harry Potter and the Chamber of Secrets (Harry...        352.0    4:706082
# 4  Harry Potter and the Prisoner of Azkaban (Harr...        435.0    4:630534
# 5  Harry Potter and the Goblet of Fire (Harry Pot...        734.0    4:606800
# 6  Harry Potter Boxed Set, Books 1-5 (Harry Potte...       2690.0      4:4650
# 7  Unauthorized Harry Potter Book Seven News: "Ha...        152.0         4:7
# 8       Harry Potter Collection (Harry Potter, #1-6)       3342.0      4:4358
# 9  The Ultimate Hitchhiker's Guide: Five Complete...        815.0     4:75683
#
#   RatingDistTotal                 Authors  Rating RatingDist5 RatingDist3
# 0   total:2298124            J.K. Rowling    4.57   5:1546466    3:159960
# 1   total:2358637            J.K. Rowling    4.50   5:1493113    3:211781
# 2   total:6587388            J.K. Rowling    4.47   5:4268227    3:567458
# 3   total:2560657            J.K. Rowling    4.42   5:1504505    3:288821
# 4   total:2610317            J.K. Rowling    4.57   5:1749958    3:194848
# 5   total:2431085            J.K. Rowling    4.56   5:1612165    3:178419
# 6     total:43968            J.K. Rowling    4.78     5:37432      3:1201
# 7        total:28  W. Frederick Zimmerman    3.79        5:10         3:6
# 8     total:30313            J.K. Rowling    4.73     5:24406      3:1074
# 9    total:274268           Douglas Adams    4.37    5:157499     3:30030

# %%
print(df.columns)
# Out:
# Index(['Name', 'pagesNumber', 'RatingDist4', 'RatingDistTotal', 'Authors',
#        'Rating', 'RatingDist5', 'RatingDist3'],
#       dtype='object')

# %% [markdown]
# *VARIABLES NÚMERICAS*

# %%
num = df.select_dtypes(include='number')
num
# Out:
#          pagesNumber  Rating
# 0              652.0    4.57
# 1              870.0    4.50
# 2              309.0    4.47
# 3              352.0    4.42
# 4              435.0    4.57
# ...              ...     ...
# 1810598        336.0    4.03
# 1810599        209.0    3.57
# 1810600        251.0    4.28
# 1810602        400.0    3.81
# 1810604         36.0    5.00
#
# [1073666 rows x 2 columns]

# %%
num.describe
# Out:
# <bound method NDFrame.describe of          pagesNumber  Rating
# 0              652.0    4.57
# 1              870.0    4.50
# 2              309.0    4.47
# 3              352.0    4.42
# 4              435.0    4.57
# ...              ...     ...
# 1810598        336.0    4.03
# 1810599        209.0    3.57
# 1810600        251.0    4.28
# 1810602        400.0    3.81
# 1810604         36.0    5.00
#
# [1073666 rows x 2 columns]>

# %%
print(num.nunique())
# Out:
# pagesNumber    2603
# Rating          149
# dtype: int64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear la figura y los ejes con un layout más ajustado
fig, axes = plt.subplots(2, 2, figsize=(12, 8))

# Crear histogramas y diagramas de caja para `pagesNumber`
sns.histplot(ax=axes[0, 0], data=df, x="pagesNumber", color='purple')
axes[0, 0].set_title('Distribución de pagesNumber')

sns.boxplot(ax=axes[1, 0], data=df, x="pagesNumber", color='hotpink')
axes[1, 0].set_title('Diagrama de caja de pagesNumber')

# Crear histogramas y diagramas de caja para `Rating`
sns.histplot(ax=axes[0, 1], data=df, x="Rating", color='green')
axes[0, 1].set_title('Distribución de Rating')

sns.boxplot(ax=axes[1, 1], data=df, x="Rating", color='orange')
axes[1, 1].set_title('Diagrama de caja de Rating')

# Ajustar el layout
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %%
print(df['pagesNumber'].describe())
# Out:
# count    1.073666e+06
# mean     2.772609e+02
# std      2.245730e+03
# min      0.000000e+00
# 25%      1.480000e+02
# 50%      2.410000e+02
# 75%      3.490000e+02
# max      2.254246e+06
# Name: pagesNumber, dtype: float64

# %% [markdown]
# Al realizar el cuadro anterior pude observar que habían libros que tenían demasiadas páginas iban desde las 100 hasta las más de 4000 entonces decidí filtrar y crear unas columnas adicionales para libros o colecciones con una extensión demasiado grandes, hay incluso enciclopedias con una extención de más de 30000 páginas.

# %% [markdown]
# Pasé los libros con "boxed set, colection o encyclopedia" a una lista a parte la cual ahora dividiré en 4 categorias Libros individuales estándar, Libros individuales largos, Colecciones y Enciclopedias.

# %%
import pandas as pd

# Marcar las colecciones y enciclopedias conocidas
df['is_collection'] = df['Name'].str.contains('Collection|Boxed Set|Complete|Encyclopedia', case=False)

def categorize_book(row):
    if row['is_collection']:
        return 'Collection/Encyclopedia'
    elif row['pagesNumber'] <= 250:
        return 'Short Book'
    elif 251 <= row['pagesNumber'] <= 1000:
        return 'Long Book'
    elif 1001 <= row['pagesNumber'] <= 2000:
        return 'Collection'
    else:
        return 'Encyclopedia'

df['book_category'] = df.apply(categorize_book, axis=1)

# Mostrar las primeras filas para verificar
print(df.head())
# Out:
#                                                 Name  pagesNumber RatingDist4  \
# 0  Harry Potter and the Half-Blood Prince (Harry ...        652.0    4:556485
# 1  Harry Potter and the Order of the Phoenix (Har...        870.0    4:604283
# 2  Harry Potter and the Sorcerer's Stone (Harry P...        309.0   4:1513191
# 3  Harry Potter and the Chamber of Secrets (Harry...        352.0    4:706082
# 4  Harry Potter and the Prisoner of Azkaban (Harr...        435.0    4:630534
#
#   RatingDistTotal       Authors  Rating RatingDist5 RatingDist3  \
# 0   total:2298124  J.K. Rowling    4.57   5:1546466    3:159960
# 1   total:2358637  J.K. Rowling    4.50   5:1493113    3:211781
# 2   total:6587388  J.K. Rowling    4.47   5:4268227    3:567458
# 3   total:2560657  J.K. Rowling    4.42   5:1504505    3:288821
# 4   total:2610317  J.K. Rowling    4.57   5:1749958    3:194848
#
#    is_collection book_category
# 0          False     Long Book
# 1          False     Long Book
# 2          False     Long Book
# 3          False     Long Book
# 4          False     Long Book

# %%
df.book_category
# Out:
# 0           Long Book
# 1           Long Book
# 2           Long Book
# 3           Long Book
# 4           Long Book
#               ...
# 1810598     Long Book
# 1810599    Short Book
# 1810600     Long Book
# 1810602     Long Book
# 1810604    Short Book
# Name: book_category, Length: 1073666, dtype: object

# %%
import pandas as pd

# Filtrar el DataFrame por cada categoría
df_cortos = df[df['book_category'] == 'Short Book']
df_largos = df[df['book_category'] == 'Long Book']
df_colecciones_enciclopedias = df[df['book_category'] == 'Collection/Encyclopedia']

# Análisis descriptivo para libros cortos
print("Análisis de Libros Cortos")
print(df_cortos.describe(include='all'))

# Análisis descriptivo para libros largos
print("\nAnálisis de Libros Largos")
print(df_largos.describe(include='all'))

# Análisis descriptivo para colecciones y enciclopedias
print("\nAnálisis de Colecciones y Enciclopedias")
print(df_colecciones_enciclopedias.describe(include='all'))

# Si quieres ver la distribución de una columna específica, por ejemplo, 'average_rating'
print("\nDistribución de Ratings de Libros Cortos")
print(df_cortos['Rating'].describe())

print("\nDistribución de Ratings de Libros Largos")
print(df_largos['Rating'].describe())

print("\nDistribución de Ratings de Colecciones y Enciclopedias")
print(df_colecciones_enciclopedias['Rating'].describe())
# Out:
# Análisis de Libros Cortos
#               Name    pagesNumber RatingDist4 RatingDistTotal  \
# count       551291  551291.000000      551291          551291
# unique      494419            NaN       15982           23927
# top     The Prince            NaN         4:1         total:1
# freq            20            NaN       92894           63367
# mean           NaN     142.183654         NaN             NaN
# std            NaN      72.111190         NaN             NaN
# min            NaN       0.000000         NaN             NaN
# 25%            NaN      84.000000         NaN             NaN
# 50%            NaN     155.000000         NaN             NaN
# 75%            NaN     204.000000         NaN             NaN
# max            NaN     250.000000         NaN             NaN
#
#                     Authors         Rating RatingDist5 RatingDist3  \
# count                551291  551291.000000      551291      551291
# unique               219226            NaN       16510       13453
# top     William Shakespeare            NaN         5:1         3:0
# freq                    679            NaN       97617      139156
# mean                    NaN       4.064329         NaN         NaN
# std                     NaN       0.398865         NaN         NaN
# min                     NaN       3.500000         NaN         NaN
# 25%                     NaN       3.780000         NaN         NaN
# 50%                     NaN       4.000000         NaN         NaN
# 75%                     NaN       4.250000         NaN         NaN
# max                     NaN       5.000000         NaN         NaN
#
#        is_collection book_category
# count         551291        551291
# unique             1             1
# top            False    Short Book
# freq          551291        551291
# mean             NaN           NaN
# std              NaN           NaN
# min              NaN           NaN
# 25%              NaN           NaN
# 50%              NaN           NaN
# 75%              NaN           NaN
# max              NaN           NaN
#
# Análisis de Libros Largos
#                   Name    pagesNumber RatingDist4 RatingDistTotal    Authors  \
# count           495600  495600.000000      495600          495600     495600
# unique          421890            NaN       20665           30416     199437
# top     Mansfield Park            NaN         4:1         total:1  Anonymous
# freq                18            NaN       66577           46215        582
# mean               NaN     391.660305         NaN             NaN        NaN
# std                NaN     137.572632         NaN             NaN        NaN
# min                NaN     251.000000         NaN             NaN        NaN
# 25%                NaN     292.000000         NaN             NaN        NaN
# 50%                NaN     352.000000         NaN             NaN        NaN
# 75%                NaN     445.000000         NaN             NaN        NaN
# max                NaN    1000.000000         NaN             NaN        NaN
#
#                Rating RatingDist5 RatingDist3 is_collection book_category
# count   495600.000000      495600      495600        495600        495600
# unique            NaN       20471       16648             1             1
# top               NaN         5:1         3:0         False     Long Book
# freq              NaN       68529      102826        495600        495600
# mean         4.038521         NaN         NaN           NaN           NaN
# std          0.368666         NaN         NaN           NaN           NaN
# min          3.500000         NaN         NaN           NaN           NaN
# 25%          3.780000         NaN         NaN           NaN           NaN
# 50%          4.000000         NaN         NaN           NaN           NaN
# 75%          4.200000         NaN         NaN           NaN           NaN
# max          5.000000         NaN         NaN           NaN           NaN
#
# Análisis de Colecciones y Enciclopedias
#                       Name   pagesNumber RatingDist4 RatingDistTotal  \
# count                16539  16539.000000       16539           16539
# unique               15384           NaN        1154            1680
# top     The Complete Poems           NaN         4:1         total:1
# freq                    13           NaN        2853            1847
# mean                   NaN    391.860330         NaN             NaN
# std                    NaN    534.188416         NaN             NaN
# min                    NaN      0.000000         NaN             NaN
# 25%                    NaN    182.000000         NaN             NaN
# 50%                    NaN    289.000000         NaN             NaN
# 75%                    NaN    456.000000         NaN             NaN
# max                    NaN  29935.000000         NaN             NaN
#
#                                  Authors        Rating RatingDist5  \
# count                              16539  16539.000000       16539
# unique                             10703           NaN        1293
# top     Fodor's Travel Publications Inc.           NaN         5:1
# freq                                  98           NaN        2881
# mean                                 NaN      4.159987         NaN
# std                                  NaN      0.398428         NaN
# min                                  NaN      3.500000         NaN
# 25%                                  NaN      3.890000         NaN
# 50%                                  NaN      4.080000         NaN
# 75%                                  NaN      4.400000         NaN
# max                                  NaN      5.000000         NaN
#
#        RatingDist3 is_collection            book_category
# count        16539         16539                    16539
# unique         911             1                        1
# top            3:0          True  Collection/Encyclopedia
# freq          4582         16539                    16539
# mean           NaN           NaN                      NaN
# std            NaN           NaN                      NaN
# min            NaN           NaN                      NaN
# 25%            NaN           NaN                      NaN
# 50%            NaN           NaN                      NaN
# 75%            NaN           NaN                      NaN
# max            NaN           NaN                      NaN
#
# Distribución de Ratings de Libros Cortos
# count    551291.000000
# mean          4.064329
# std           0.398865
# min           3.500000
# 25%           3.780000
# 50%           4.000000
# 75%           4.250000
# max           5.000000
# Name: Rating, dtype: float64
#
# Distribución de Ratings de Libros Largos
# count    495600.000000
# mean          4.038521
# std           0.368666
# min           3.500000
# 25%           3.780000
# 50%           4.000000
# 75%           4.200000
# max           5.000000
# Name: Rating, dtype: float64
#
# Distribución de Ratings de Colecciones y Enciclopedias
# count    16539.000000
# mean         4.159987
# std          0.398428
# min          3.500000
# 25%          3.890000
# 50%          4.080000
# 75%          4.400000
# max          5.000000
# Name: Rating, dtype: float64

# %%
# Libros estándar
sns.histplot(data=df[df['book_category'] == 'Short Book'], x="pagesNumber", color='purple')
plt.title('Distribución de número de páginas - Libros cortos')
plt.show()

# Libros largos
sns.histplot(data=df[df['book_category'] == 'Long Book'], x="pagesNumber", color='pink')
plt.title('Distribución de número de páginas - Libros Largos')
plt.show()

# Colecciones y Enciclopedias
sns.histplot(data=df[df['book_category'] == 'Collection/Encyclopedia'], x="pagesNumber", color='green')
plt.title('Distribución de número de páginas - Colecciones y Enciclopedias')
plt.show()

# %% [markdown]
# Al realizar esta gráfica pude observar que hay muchos libros que tienen 0 páginas, los cuales procederé a eliminar

# %%
import pandas as pd

# Filtrar los libros que tienen 0 páginas
df_0_paginas = df[df['pagesNumber'] == 0]

# Mostrar los resultados
print("Libros con 0 páginas")
print(df_0_paginas)
# Out:
# Libros con 0 páginas
#                                                       Name  pagesNumber  \
# 615      The 5 Love Languages / The 5 Love Languages Jo...          0.0
# 649                 Think and Grow Rich: Instant Motivator          0.0
# 667                                                  Trump          0.0
# 701      Secrets of the Super [Football] Athletes: Tips...          0.0
# 817                                            Kiowa Trail          0.0
# ...                                                    ...          ...
# 1810123             The Da Vinci Code (Robert Langdon, #2)          0.0
# 1810190                                        Fan's Notes          0.0
# 1810354  Shrub: the Short But Happy Political Life of G...          0.0
# 1810375  The Loved Dog: The Playful, Nonaggressive Way ...          0.0
# 1810386                        Another Roadside Attraction          0.0
#
#         RatingDist4 RatingDistTotal          Authors  Rating RatingDist5  \
# 615             4:7        total:29     Gary Chapman    4.69        5:21
# 649         4:52820    total:191158    Napoleon Hill    4.18     5:96063
# 667            4:88       total:398  Donald J. Trump    3.55       5:129
# 701             4:0         total:1    Abbot Solomon    5.00         5:1
# 817           4:720      total:2041    Louis L'Amour    3.95       5:656
# ...             ...             ...              ...     ...         ...
# 1810123    4:648946   total:1876798        Dan Brown    3.85    5:620194
# 1810190      4:1216      total:3831  Frederick Exley    4.08      5:1657
# 1810354       4:867      total:2226      Molly Ivins    4.09       5:853
# 1810375       4:356       total:988     Tamar Geller    3.83       5:287
# 1810386     4:11786     total:30883      Tom Robbins    3.98     5:10346
#
#         RatingDist3  is_collection book_category
# 615             3:1          False    Short Book
# 649         3:28227          False    Short Book
# 667            3:97          False    Short Book
# 701             3:0          False    Short Book
# 817           3:572          False    Short Book
# ...             ...            ...           ...
# 1810123    3:390587          False    Short Book
# 1810190       3:657          False    Short Book
# 1810354       3:397          False    Short Book
# 1810375       3:252          False    Short Book
# 1810386      3:6990          False    Short Book
#
# [8697 rows x 10 columns]

# %%
import pandas as pd

# Filtrar los libros con entre 0 y 4 páginas
df_filtrado = df[~df['pagesNumber'].between(0, 4)]

# Guardar el DataFrame filtrado en un nuevo archivo CSV
df_filtrado.to_csv('C:\\Users\\Fukushima\\Documents\\GitHub\\ProyectoFinalVV\\data\\raw\\booksfiltrados.csv', index=False)

# Mostrar los resultados
print("Número de libros restantes después de eliminar libros con 0-4 páginas:")
print(df_filtrado.shape[0])
# Out:
# Número de libros restantes después de eliminar libros con 0-4 páginas:
# 1060441

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Filtrar los DataFrames por categoría
df_short_books = df_filtrado[df_filtrado['book_category'] == 'Short Book']
df_long_books = df_filtrado[df_filtrado['book_category'] == 'Long Book']
df_collections_enciclopedias = df_filtrado[df_filtrado['book_category'] == 'Collection/Encyclopedia']

# Crear la figura y los ejes con un layout ajustado
fig, axes = plt.subplots(3, 4, figsize=(16, 12))

# Crear histogramas y diagramas de caja para `pagesNumber` en cada categoría
sns.histplot(ax=axes[0, 0], data=df_short_books, x="pagesNumber", color='purple')
axes[0, 0].set_title('Distribución de pagesNumber - Libros Cortos')

sns.boxplot(ax=axes[1, 0], data=df_short_books, x="pagesNumber", color='hotpink')
axes[1, 0].set_title('Diagrama de caja de pagesNumber - Libros Cortos')

sns.histplot(ax=axes[0, 1], data=df_long_books, x="pagesNumber", color='purple')
axes[0, 1].set_title('Distribución de pagesNumber - Libros Largos')

sns.boxplot(ax=axes[1, 1], data=df_long_books, x="pagesNumber", color='hotpink')
axes[1, 1].set_title('Diagrama de caja de pagesNumber - Libros Largos')

sns.histplot(ax=axes[0, 2], data=df_collections_enciclopedias, x="pagesNumber", color='purple')
axes[0, 2].set_title('Distribución de pagesNumber - Colecciones/Enciclopedias')

sns.boxplot(ax=axes[1, 2], data=df_collections_enciclopedias, x="pagesNumber", color='hotpink')
axes[1, 2].set_title('Diagrama de caja de pagesNumber - Colecciones/Enciclopedias')

# Crear histogramas y diagramas de caja para `Rating` en cada categoría
sns.histplot(ax=axes[0, 3], data=df_short_books, x="Rating", color='green')
axes[0, 3].set_title('Distribución de Rating - Libros Cortos')

sns.boxplot(ax=axes[1, 3], data=df_short_books, x="Rating", color='orange')
axes[1, 3].set_title('Diagrama de caja de Rating - Libros Cortos')

sns.histplot(ax=axes[2, 0], data=df_long_books, x="Rating", color='green')
axes[2, 0].set_title('Distribución de Rating - Libros Largos')

sns.boxplot(ax=axes[2, 1], data=df_long_books, x="Rating", color='orange')
axes[2, 1].set_title('Diagrama de caja de Rating - Libros Largos')

sns.histplot(ax=axes[2, 2], data=df_collections_enciclopedias, x="Rating", color='green')
axes[2, 2].set_title('Distribución de Rating - Colecciones/Enciclopedias')

sns.boxplot(ax=axes[2, 3], data=df_collections_enciclopedias, x="Rating", color='orange')
axes[2, 3].set_title('Diagrama de caja de Rating - Colecciones/Enciclopedias')

# Ajustar el layout
plt.tight_layout()

# Mostrar el gráfico
plt.show()

# %% [markdown]
# Con las variables númericas ya gráficadas y filtradas paso a las variables categóricas
#
# **Variables categóricas**

# %%
categoricas = df_filtrado.select_dtypes(include='object')
categoricas
# Out:
#                                                       Name RatingDist4  \
# 0        Harry Potter and the Half-Blood Prince (Harry ...    4:556485
# 1        Harry Potter and the Order of the Phoenix (Har...    4:604283
# 2        Harry Potter and the Sorcerer's Stone (Harry P...   4:1513191
# 3        Harry Potter and the Chamber of Secrets (Harry...    4:706082
# 4        Harry Potter and the Prisoner of Azkaban (Harr...    4:630534
# ...                                                    ...         ...
# 1810598  Gender Talk: The Struggle For Women's Equality...        4:11
# 1810599         School Talk: Gender and Adolescent Culture        4:10
# 1810600  Gendered Talk at Work: Constructing Gender Ide...         4:3
# 1810602  Would You Rather . . . ?: The Outrageous Book ...        4:35
# 1810604                                     Within/Without         4:0
#
#         RatingDistTotal                Authors RatingDist5 RatingDist3  \
# 0         total:2298124           J.K. Rowling   5:1546466    3:159960
# 1         total:2358637           J.K. Rowling   5:1493113    3:211781
# 2         total:6587388           J.K. Rowling   5:4268227    3:567458
# 3         total:2560657           J.K. Rowling   5:1504505    3:288821
# 4         total:2610317           J.K. Rowling   5:1749958    3:194848
# ...                 ...                    ...         ...         ...
# 1810598        total:59  Johnnetta Betsch Cole        5:27        3:18
# 1810599        total:23             Donna Eder         5:2        3:10
# 1810600        total:25          Janet  Holmes        5:15         3:6
# 1810602       total:121             Randy Horn        5:39        3:34
# 1810604         total:2      Kathryn T.S. Bass         5:2         3:0
#
#         book_category
# 0           Long Book
# 1           Long Book
# 2           Long Book
# 3           Long Book
# 4           Long Book
# ...               ...
# 1810598     Long Book
# 1810599    Short Book
# 1810600     Long Book
# 1810602     Long Book
# 1810604    Short Book
#
# [1060441 rows x 7 columns]

# %%
print(categoricas.nunique())
# Out:
# Name               915190
# RatingDist4         27447
# RatingDistTotal     41177
# Authors            362082
# RatingDist5         27984
# RatingDist3         22245
# book_category           5
# dtype: int64

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# Crear una paleta personalizada en la gama de rosa y morado
paleta_rosa_morado = sns.color_palette(["#FF69B4", "#DB7093", "#C71585", "#800080", "#DA70D6", "#BA55D3", "#EE82EE"])

# Gráfico de conteo para autores
plt.figure(figsize=(10, 6))
sns.countplot(y=df['Authors'], order=df_filtrado['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
plt.title('Top 10 autores Más Frecuentes')
plt.xlabel('Frecuencia')
plt.ylabel('Libros')
plt.show()

# Gráfico de conteo para publicistas
plt.figure(figsize=(10, 6))
sns.countplot(y=df['book_category'], order=df_filtrado['book_category'].value_counts().index[:10], palette=paleta_rosa_morado)
plt.title('Top 10 categoria Más Frecuentes')
plt.xlabel('Frecuencia')
plt.ylabel('Categorias')
plt.show()
# Out:
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_16148\1190575293.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['Authors'], order=df_filtrado['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_16148\1190575293.py:9: UserWarning:
# The palette list has fewer values (7) than needed (10) and will cycle, which may produce an uninterpretable plot.
#   sns.countplot(y=df['Authors'], order=df_filtrado['Authors'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_16148\1190575293.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=df['book_category'], order=df_filtrado['book_category'].value_counts().index[:10], palette=paleta_rosa_morado)
# C:\Users\Fukushima\AppData\Local\Temp\ipykernel_16148\1190575293.py:17: UserWarning: The palette list has more values (7) than needed (5), which may not be intended.
#   sns.countplot(y=df['book_category'], order=df_filtrado['book_category'].value_counts().index[:10], palette=paleta_rosa_morado)

# %%
print(df_filtrado.dtypes)
# Out:
# Name                object
# pagesNumber        float64
# RatingDist4         object
# RatingDistTotal     object
# Authors             object
# Rating             float64
# RatingDist5         object
# RatingDist3         object
# is_collection         bool
# book_category       object
# dtype: object

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Crear la figura y el eje
plt.figure(figsize=(10, 6))

# Graficar el histograma
sns.histplot(df_filtrado['Rating'], bins=20, color='purple', kde=True)
plt.title('Distribución de Ratings de Libros')
plt.xlabel('Rating')
plt.ylabel('Frecuencia')

# Ajustar el layout
plt.tight_layout()

# Mostrar el gráfico
plt.show()
